# %%
#already installed on my machine
#%pip install flair

# %%
from flair import datasets

corpus = datasets.UD_ENGLISH()

# %%
print(corpus)
# Out:
# Corpus: 12544 train + 2001 dev + 2077 test sentences

# %%
train_dataset = corpus.train

# %%
sentence = train_dataset[2]
print(sentence)
# Out:
# Sentence: "DPA : Iraqi authorities announced that they had busted up 3 terrorist cells operating in Baghdad ." → ["DPA"/DPA/PROPN/NNP/root/Sing, ":"/:/PUNCT/:/punct, "Iraqi"/Iraqi/ADJ/JJ/amod/Pos, "authorities"/authority/NOUN/NNS/nsubj/Plur, "announced"/announce/VERB/VBD/parataxis/Ind/Plur/3/Past/Fin, "that"/that/SCONJ/IN/mark, "they"/they/PRON/PRP/nsubj/Nom/Plur/3/Prs, "had"/have/AUX/VBD/aux/Ind/Plur/3/Past/Fin, "busted"/bust/VERB/VBN/ccomp/Past/Part, "up"/up/ADP/RP/compound:prt, "3"/3/NUM/CD/nummod/Digit/Card, "terrorist"/terrorist/ADJ/JJ/amod/Pos, "cells"/cell/NOUN/NNS/obj/Plur, "operating"/operate/VERB/VBG/acl/Ger, "in"/in/ADP/IN/case, "Baghdad"/Baghdad/PROPN/NNP/obl/Sing, "."/./PUNCT/./punct]

# %%
corpus.downsample(0.01) # quals 1% of the original corpus

# %%
print(corpus)
# Out:
# Corpus: 125 train + 20 dev + 21 test sentences
