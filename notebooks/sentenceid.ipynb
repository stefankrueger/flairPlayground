# %%
import csv
import pandas as pd
import numpy as np
import math # for isnan check
filepath = '../data/ler/ler.conll'

# %%
df = pd.read_csv(filepath, sep=' ', header=None, names=['token','tag'], quoting=csv.QUOTE_NONE,skip_blank_lines=False)

# %%
test = df.head(50)

# %%
Sentence_ID = 0
test['sentence_id'] = test['token'].apply(lambda x: Sentence_ID if not pd.isnull(x) else -1)
# Out:
# /tmp/ipykernel_54345/1904511927.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['sentence_id'] = test['token'].apply(lambda x: Sentence_ID if not pd.isnull(x) else -1)

# %%
test['sentence_id'].astype(int) # else sentence_id would be float
test.dtypes
# Out:
# token          object
# tag            object
# sentence_id     int64
# dtype: object

# %%
test.head(50)
# Out:
#                    token   tag  sentence_id
# 0     Prozesskostenhilfe     O            0
# 1                      -     O            0
# 2          Entschädigung     O            0
# 3                    für     O            0
# 4              überlange     O            0
# 5        Verfahrensdauer     O            0
# 6                      -     O            0
# 7     Revisionsverfahren     O            0
# 8                    NaN   NaN           -1
# 9                    Der     O            0
# 10                Antrag     O            0
# 11                   auf     O            0
# 12             Gewährung     O            0
# 13                   von     O            0
# 14    Prozesskostenhilfe     O            0
# 15                 nebst     O            0
# 16            Beiordnung     O            0
# 17                   von     O            0
# 18                 Herrn     O            0
# 19          Rechtsanwalt     O            0
# 20                     F  B-AN            0
# 21                   für     O            0
# 22                   die     O            0
# 23         beabsichtigte     O            0
# 24             Einlegung     O            0
# 25                 einer     O            0
# 26   Entschädigungsklage     O            0
# 27          hinsichtlich     O            0
# 28                   der     O            0
# 29                 Dauer     O            0
# 30                   des     O            0
# 31            Verfahrens  B-RS            0
# 32                   vor  I-RS            0
# 33                   dem  I-RS            0
# 34  Bundesarbeitsgericht  I-RS            0
# 35                   zum  I-RS            0
# 36          Aktenzeichen  I-RS            0
# 37                     -  I-RS            0
# 38                     8  I-RS            0
# 39                   AZR  I-RS            0
# 40                418/15  I-RS            0
# 41                     -  I-RS            0
# 42                  wird     O            0
# 43        zurückgewiesen     O            0
# 44                     .     O            0
# 45                   NaN   NaN           -1
# 46                    I.     O            0
# 47                   Der     O            0
# 48                Antrag     O            0
# 49                   auf     O            0

# %%
check_nan = test['token'].isnull()
print (check_nan)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45     True
# 46    False
# 47    False
# 48    False
# 49    False
# Name: token, dtype: bool

# %%
def build_sentence_ids():
    ID = 0
    last_one_was_minus_one = False
    for index, value in test['sentence_id'].items():
        if(not last_one_was_minus_one) and test.at[index,'sentence_id'] != -1:
            test.at[index,'sentence_id'] = ID
            last_one_Was_minus_one=False
        elif(last_one_was_minus_one):
            test.at[index,'sentence_id'] = ID
            last_one_was_minus_one=False
        else:
            last_one_was_minus_one=True
            ID = ID + 1

# %%
build_sentence_ids()
test.head(100)
# Out:
#                    token   tag  sentence_id
# 0     Prozesskostenhilfe     O            0
# 1                      -     O            0
# 2          Entschädigung     O            0
# 3                    für     O            0
# 4              überlange     O            0
# 5        Verfahrensdauer     O            0
# 6                      -     O            0
# 7     Revisionsverfahren     O            0
# 8                    NaN   NaN           -1
# 9                    Der     O            1
# 10                Antrag     O            1
# 11                   auf     O            1
# 12             Gewährung     O            1
# 13                   von     O            1
# 14    Prozesskostenhilfe     O            1
# 15                 nebst     O            1
# 16            Beiordnung     O            1
# 17                   von     O            1
# 18                 Herrn     O            1
# 19          Rechtsanwalt     O            1
# 20                     F  B-AN            1
# 21                   für     O            1
# 22                   die     O            1
# 23         beabsichtigte     O            1
# 24             Einlegung     O            1
# 25                 einer     O            1
# 26   Entschädigungsklage     O            1
# 27          hinsichtlich     O            1
# 28                   der     O            1
# 29                 Dauer     O            1
# 30                   des     O            1
# 31            Verfahrens  B-RS            1
# 32                   vor  I-RS            1
# 33                   dem  I-RS            1
# 34  Bundesarbeitsgericht  I-RS            1
# 35                   zum  I-RS            1
# 36          Aktenzeichen  I-RS            1
# 37                     -  I-RS            1
# 38                     8  I-RS            1
# 39                   AZR  I-RS            1
# 40                418/15  I-RS            1
# 41                     -  I-RS            1
# 42                  wird     O            1
# 43        zurückgewiesen     O            1
# 44                     .     O            1
# 45                   NaN   NaN           -1
# 46                    I.     O            2
# 47                   Der     O            2
# 48                Antrag     O            2
# 49                   auf     O            2

# %%
df2=test.dropna(subset=['token']).reset_index(drop=True)
df2.head(50)
# Out:
#                    token   tag  sentence_id
# 0     Prozesskostenhilfe     O            0
# 1                      -     O            0
# 2          Entschädigung     O            0
# 3                    für     O            0
# 4              überlange     O            0
# 5        Verfahrensdauer     O            0
# 6                      -     O            0
# 7     Revisionsverfahren     O            0
# 8                    Der     O            1
# 9                 Antrag     O            1
# 10                   auf     O            1
# 11             Gewährung     O            1
# 12                   von     O            1
# 13    Prozesskostenhilfe     O            1
# 14                 nebst     O            1
# 15            Beiordnung     O            1
# 16                   von     O            1
# 17                 Herrn     O            1
# 18          Rechtsanwalt     O            1
# 19                     F  B-AN            1
# 20                   für     O            1
# 21                   die     O            1
# 22         beabsichtigte     O            1
# 23             Einlegung     O            1
# 24                 einer     O            1
# 25   Entschädigungsklage     O            1
# 26          hinsichtlich     O            1
# 27                   der     O            1
# 28                 Dauer     O            1
# 29                   des     O            1
# 30            Verfahrens  B-RS            1
# 31                   vor  I-RS            1
# 32                   dem  I-RS            1
# 33  Bundesarbeitsgericht  I-RS            1
# 34                   zum  I-RS            1
# 35          Aktenzeichen  I-RS            1
# 36                     -  I-RS            1
# 37                     8  I-RS            1
# 38                   AZR  I-RS            1
# 39                418/15  I-RS            1
# 40                     -  I-RS            1
# 41                  wird     O            1
# 42        zurückgewiesen     O            1
# 43                     .     O            1
# 44                    I.     O            2
# 45                   Der     O            2
# 46                Antrag     O            2
# 47                   auf     O            2

# %%
check_nan_token = df2['token'].isnull().values.any()
check_nan_tag = df2['tag'].isnull().values.any()
check_nan_sentence_id = df2['sentence_id'].isnull().values.any()
print (check_nan_token)
print (check_nan_tag)
print (check_nan_sentence_id)
# Out:
# False
# False
# False
